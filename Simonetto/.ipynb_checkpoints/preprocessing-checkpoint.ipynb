# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import datetime

# %% [markdown]
# # Loading up the network

# %%
#getting the set of edges which describe the network
edges = pd.read_csv('mny.rnet',
                    sep=' ',
                    names=['ID_edge',
                          'from_ID',
                          'to_ID',
                          'from_x',
                          'from_y',
                          'to_x',
                          'to_y'])
edges
# Out:
#        ID_edge  from_ID  to_ID     from_x     from_y       to_x       to_y
# 0            0        1      2 -73.978969  40.783390 -73.979568  40.783650
# 1            1        2      1 -73.979568  40.783650 -73.978969  40.783390
# 2            2        3      4 -73.991688  40.738045 -73.991019  40.737764
# 3            3        4      3 -73.991019  40.737764 -73.991688  40.738045
# 4            4        5      6 -73.931611  40.800105 -73.931214  40.799478
# ...        ...      ...    ...        ...        ...        ...        ...
# 31439    31439    12087   5826 -74.002284  40.743017 -74.001587  40.742735
# 31440    31440     1407  12318 -73.974540  40.746211 -73.973978  40.746062
# 31441    31441    12318   1407 -73.973978  40.746062 -73.974540  40.746211
# 31442    31442    12060  11570 -73.936115  40.797205 -73.935504  40.796956
# 31443    31443    11570  12060 -73.935504  40.796956 -73.936115  40.797205
#
# [31444 rows x 7 columns]

# %%
nodes_from=edges[['from_ID','from_x','from_y']]
nodes_from.columns=['id','x','y']
nodes_from
# Out:
#           id          x          y
# 0          1 -73.978969  40.783390
# 1          2 -73.979568  40.783650
# 2          3 -73.991688  40.738045
# 3          4 -73.991019  40.737764
# 4          5 -73.931611  40.800105
# ...      ...        ...        ...
# 31439  12087 -74.002284  40.743017
# 31440   1407 -73.974540  40.746211
# 31441  12318 -73.973978  40.746062
# 31442  12060 -73.936115  40.797205
# 31443  11570 -73.935504  40.796956
#
# [31444 rows x 3 columns]

# %%
nodes_to=edges[['to_ID','to_x','to_y']]
nodes_to.columns=['id','x','y']
nodes_to
# Out:
#           id          x          y
# 0          2 -73.979568  40.783650
# 1          1 -73.978969  40.783390
# 2          4 -73.991019  40.737764
# 3          3 -73.991688  40.738045
# 4          6 -73.931214  40.799478
# ...      ...        ...        ...
# 31439   5826 -74.001587  40.742735
# 31440  12318 -73.973978  40.746062
# 31441   1407 -73.974540  40.746211
# 31442  11570 -73.935504  40.796956
# 31443  12060 -73.936115  40.797205
#
# [31444 rows x 3 columns]

# %%
nodes=pd.concat([nodes_from,nodes_to],ignore_index=True)
nodes
# Out:
#           id          x          y
# 0          1 -73.978969  40.783390
# 1          2 -73.979568  40.783650
# 2          3 -73.991688  40.738045
# 3          4 -73.991019  40.737764
# 4          5 -73.931611  40.800105
# ...      ...        ...        ...
# 62883   5826 -74.001587  40.742735
# 62884  12318 -73.973978  40.746062
# 62885   1407 -73.974540  40.746211
# 62886  11570 -73.935504  40.796956
# 62887  12060 -73.936115  40.797205
#
# [62888 rows x 3 columns]

# %%
print("Min and Max node ID")
print(min(nodes['id']))
print(max(nodes['id']))
# Out:
# Min and Max node ID
# 1
# 12320

# %%
#filter out duplicates (i.e where the ID, x and y coord are all the same)
nodes=nodes.drop_duplicates(subset=['id','x','y'])
nodes.set_index('id',inplace=True)
nodes
# Out:
#                x          y
# id
# 1     -73.978969  40.783390
# 2     -73.979568  40.783650
# 3     -73.991688  40.738045
# 4     -73.991019  40.737764
# 5     -73.931611  40.800105
# ...          ...        ...
# 12316 -73.986592  40.773109
# 12317 -73.913304  40.876437
# 12318 -73.973978  40.746062
# 12319 -73.945929  40.799538
# 12320 -73.934412  40.828131
#
# [12320 rows x 2 columns]

# %%
plt.figure(figsize=(20,20))
plt.scatter(nodes.x,nodes.y)
plt.show()

# %% [markdown]
# # Extracting the vaild requests

# %%
raw = pd.read_csv('./yellow_tripdata_2013-05.csv')
raw
# Out:
# /home/keith/miniconda3/envs/dissertation/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0              VTS  2013-05-01 00:04:00  2013-05-01 00:12:00                1
# 1              VTS  2013-05-01 00:03:00  2013-05-01 00:10:00                5
# 2              VTS  2013-05-01 00:04:00  2013-05-01 00:10:00                2
# 3              VTS  2013-05-01 00:05:00  2013-05-01 00:09:00                1
# 4              VTS  2013-05-01 00:05:00  2013-05-01 00:14:00                1
# ...            ...                  ...                  ...              ...
# 15285044       VTS  2013-05-05 13:18:00  2013-05-05 13:23:00                1
# 15285045       VTS  2013-05-05 12:50:00  2013-05-05 13:25:00                5
# 15285046       VTS  2013-05-05 13:11:00  2013-05-05 13:22:00                1
# 15285047       VTS  2013-05-05 11:33:00  2013-05-05 11:35:00                1
# 15285048       VTS  2013-05-05 11:37:00  2013-05-05 11:38:00                5
#
#           trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0                  1.34        -73.982287        40.772815          1
# 1                  2.60        -73.963010        40.711900          1
# 2                  1.31        -73.981780        40.724352          1
# 3                  0.82        -73.964017        40.709692          1
# 4                  1.65        -73.973917        40.752787          1
# ...                 ...               ...              ...        ...
# 15285044           0.81        -74.009787        40.725822          1
# 15285045          13.34        -73.973995        40.742452          1
# 15285046           0.84        -73.964297        40.770562          1
# 15285047           0.73        -73.988800        40.729947          1
# 15285048           0.50        -73.958405        40.764525          1
#
#          store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                       NaN         -73.986210         40.758742          CSH
# 1                       NaN         -73.991875         40.721917          CRD
# 2                       NaN         -73.973755         40.736892          CRD
# 3                       NaN         -73.950895         40.710972          CSH
# 4                       NaN         -73.996203         40.755867          CRD
# ...                     ...                ...               ...          ...
# 15285044                NaN         -73.998197         40.725125          CSH
# 15285045                NaN         -73.922498         40.879372          CRD
# 15285046                NaN         -73.963378         40.761927          CSH
# 15285047                NaN         -73.985800         40.738190          CSH
# 15285048                NaN         -73.957477         40.769412          CSH
#
#           fare_amount  surcharge  mta_tax  tip_amount  tolls_amount  \
# 0                 7.0        0.5      0.5         0.0          0.00
# 1                 9.5        0.5      0.5         2.0          0.00
# 2                 6.5        0.5      0.5         1.0          0.00
# 3                 5.5        0.5      0.5         0.0          0.00
# 4                 8.5        0.5      0.5         1.8          0.00
# ...               ...        ...      ...         ...           ...
# 15285044          5.5        0.0      0.5         0.0          0.00
# 15285045         41.5        0.0      0.5         8.3          4.88
# 15285046          8.5        0.0      0.5         0.0          0.00
# 15285047          4.5        0.0      0.5         0.0          0.00
# 15285048          3.5        0.0      0.5         0.0          0.00
#
#           total_amount
# 0                 8.00
# 1                12.50
# 2                 8.50
# 3                 6.50
# 4                11.30
# ...                ...
# 15285044          6.00
# 15285045         55.18
# 15285046          9.00
# 15285047          5.00
# 15285048          4.00
#
# [15285049 rows x 18 columns]

# %%
requests = raw[['pickup_datetime','passenger_count',
                'pickup_longitude','pickup_latitude',
                'dropoff_longitude','dropoff_latitude']]
requests
# Out:
#               pickup_datetime  passenger_count  pickup_longitude  \
# 0         2013-05-01 00:04:00                1        -73.982287
# 1         2013-05-01 00:03:00                5        -73.963010
# 2         2013-05-01 00:04:00                2        -73.981780
# 3         2013-05-01 00:05:00                1        -73.964017
# 4         2013-05-01 00:05:00                1        -73.973917
# ...                       ...              ...               ...
# 15285044  2013-05-05 13:18:00                1        -74.009787
# 15285045  2013-05-05 12:50:00                5        -73.973995
# 15285046  2013-05-05 13:11:00                1        -73.964297
# 15285047  2013-05-05 11:33:00                1        -73.988800
# 15285048  2013-05-05 11:37:00                5        -73.958405
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude
# 0               40.772815         -73.986210         40.758742
# 1               40.711900         -73.991875         40.721917
# 2               40.724352         -73.973755         40.736892
# 3               40.709692         -73.950895         40.710972
# 4               40.752787         -73.996203         40.755867
# ...                   ...                ...               ...
# 15285044        40.725822         -73.998197         40.725125
# 15285045        40.742452         -73.922498         40.879372
# 15285046        40.770562         -73.963378         40.761927
# 15285047        40.729947         -73.985800         40.738190
# 15285048        40.764525         -73.957477         40.769412
#
# [15285049 rows x 6 columns]

# %%
#drop all requests with a quantity of 0
requests = requests[requests.passenger_count!=0]
requests
# Out:
#               pickup_datetime  passenger_count  pickup_longitude  \
# 0         2013-05-01 00:04:00                1        -73.982287
# 1         2013-05-01 00:03:00                5        -73.963010
# 2         2013-05-01 00:04:00                2        -73.981780
# 3         2013-05-01 00:05:00                1        -73.964017
# 4         2013-05-01 00:05:00                1        -73.973917
# ...                       ...              ...               ...
# 15285044  2013-05-05 13:18:00                1        -74.009787
# 15285045  2013-05-05 12:50:00                5        -73.973995
# 15285046  2013-05-05 13:11:00                1        -73.964297
# 15285047  2013-05-05 11:33:00                1        -73.988800
# 15285048  2013-05-05 11:37:00                5        -73.958405
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude
# 0               40.772815         -73.986210         40.758742
# 1               40.711900         -73.991875         40.721917
# 2               40.724352         -73.973755         40.736892
# 3               40.709692         -73.950895         40.710972
# 4               40.752787         -73.996203         40.755867
# ...                   ...                ...               ...
# 15285044        40.725822         -73.998197         40.725125
# 15285045        40.742452         -73.922498         40.879372
# 15285046        40.770562         -73.963378         40.761927
# 15285047        40.729947         -73.985800         40.738190
# 15285048        40.764525         -73.957477         40.769412
#
# [15284924 rows x 6 columns]

# %%
requests['pickup_datetime']=pd.to_datetime(requests['pickup_datetime'])
requests.dtypes
# Out:
# pickup_datetime      datetime64[ns]
# passenger_count               int64
# pickup_longitude            float64
# pickup_latitude             float64
# dropoff_longitude           float64
# dropoff_latitude            float64
# dtype: object

# %%
start_date=datetime.datetime(year=2013,month=5,day=5,hour=0,minute=0)
end_date=datetime.datetime(year=2013,month=5,day=11,hour=23,minute=59)

requests=requests[(requests['pickup_datetime']>=start_date)
         & (requests['pickup_datetime']<=end_date)]
requests
# Out:
#              pickup_datetime  passenger_count  pickup_longitude  \
# 41       2013-05-05 12:32:00                1        -73.953742
# 42       2013-05-05 12:25:00                3        -73.977162
# 43       2013-05-05 12:22:00                4        -74.008442
# 44       2013-05-05 12:16:00                6        -74.007535
# 45       2013-05-05 11:55:00                1        -73.783890
# ...                      ...              ...               ...
# 15285044 2013-05-05 13:18:00                1        -74.009787
# 15285045 2013-05-05 12:50:00                5        -73.973995
# 15285046 2013-05-05 13:11:00                1        -73.964297
# 15285047 2013-05-05 11:33:00                1        -73.988800
# 15285048 2013-05-05 11:37:00                5        -73.958405
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude
# 41              40.775377         -73.958020         40.769212
# 42              40.792962         -73.989507         40.776632
# 43              40.744897         -74.013100         40.716730
# 44              40.733105         -73.981365         40.767167
# 45              40.646375         -74.014117         40.709700
# ...                   ...                ...               ...
# 15285044        40.725822         -73.998197         40.725125
# 15285045        40.742452         -73.922498         40.879372
# 15285046        40.770562         -73.963378         40.761927
# 15285047        40.729947         -73.985800         40.738190
# 15285048        40.764525         -73.957477         40.769412
#
# [3561516 rows x 6 columns]

# %%
requests = requests.sort_values(by='pickup_datetime')
requests
# Out:
#              pickup_datetime  passenger_count  pickup_longitude  \
# 4287562  2013-05-05 00:00:00                1        -73.986547
# 11669783 2013-05-05 00:00:00                1        -73.980487
# 11693051 2013-05-05 00:00:00                5        -73.981365
# 11693063 2013-05-05 00:00:00                3        -73.984802
# 4288430  2013-05-05 00:00:00                3        -73.992870
# ...                      ...              ...               ...
# 1688392  2013-05-11 23:59:00                1        -74.000835
# 1686842  2013-05-11 23:59:00                2        -73.990042
# 1677622  2013-05-11 23:59:00                5        -74.000077
# 1716719  2013-05-11 23:59:00                6        -73.974557
# 1676545  2013-05-11 23:59:00                1        -74.005330
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude
# 4287562         40.733752         -73.975727         40.760072
# 11669783        40.738852         -73.985895         40.722917
# 11693051        40.675097         -73.986770         40.664755
# 11693063        40.760700         -73.975267         40.757027
# 4288430         40.748915         -73.955152         40.769320
# ...                   ...                ...               ...
# 1688392         40.730847         -73.978130         40.749292
# 1686842         40.719562         -73.980780         40.733677
# 1677622         40.738435         -73.989557         40.738750
# 1716719         40.783322         -73.900717         40.769042
# 1676545         40.746105         -73.990160         40.725015
#
# [3561516 rows x 6 columns]

# %%
requests["pickup_datetime"].groupby(requests["pickup_datetime"].dt.dayofweek).count().plot(kind="bar")
plt.title('number of requests per day')
plt.show()

# %% [markdown]
# # Mapping request coordinates to nodes
